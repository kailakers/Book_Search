# %%
import csv
import pandas as pd

data_name = []
data_author = []
data_isbn10 = []
data_source = []
data_category = []
data_publishy = []
data_publiser = []
data_language = []
with open('./dataset/books_ann_ng.csv', mode='r') as csv_file:
    #csv_reader = csv.DictReader(csv_file)
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            line_count+=1
        else:
            data_name.append(row[1])
            data_author.append(row[2])
            data_isbn10.append(row[4])
            data_source.append("kaggle_books_ann_ng")
            data_category.append(None)
            data_publishy.append(None)
            data_publiser.append(None)
            data_language.append(row[6])
            line_count+=1


for i in range(len(data_language)):
    if not data_language[i] is None:
        if data_language[i].find('en') >= 0:
            data_language[i] = 'English'
        elif data_language[i].find('spa') >= 0:
            data_language[i] = 'Spanish'
        elif data_language[i] == '':
            data_language[i] = None
        elif data_language[i].find('ar') >= 0:
            data_language[i] = 'Arabic'
        elif data_language[i].find('de') >= 0:
            data_language[i] = 'German'
        elif data_language[i].find('sv') >= 0:
            data_language[i] = 'Spanish'
        elif data_language[i].find('vie') >= 0:
            data_language[i] = 'Vietnamese'
        elif data_language[i].find('pol') >= 0:
            data_language[i] = 'Bantu'
        elif data_language[i].find('fil') >= 0:
            data_language[i] = 'Filipino'
        elif data_language[i].find('per') >= 0:
            data_language[i] = 'Per'
        elif data_language[i].find('rum') >= 0:
            data_language[i] = 'Romanian'
        elif data_language[i].find('rum') >= 0:
            data_language[i] = 'Romanian'      
        elif data_language[i].find('ind') >= 0:
            data_language[i] = 'Indonesian'
        elif data_language[i].find('mul') >= 0:
            data_language[i] = 'Ksingmul'
        elif data_language[i].find('ger') >= 0:
            data_language[i] = 'German'
        elif data_language[i].find('ara') >= 0:
            data_language[i] = 'Arabic'    
        elif data_language[i].find('por') >= 0:
            data_language[i] = 'Portuguese' 
        elif data_language[i].find('grc') >= 0:
            data_language[i] = 'Ancient Greek' 
        elif data_language[i].find('jpn') >= 0:
            data_language[i] = 'Japanese'
        elif data_language[i].find('dan') >= 0:
            data_language[i] = 'Mande'
        elif data_language[i].find('zho') >= 0:
            data_language[i] = 'Chinese'
        elif data_language[i].find('nl') >= 0:
            data_language[i] = 'Dutch'
        elif data_language[i].find('ita') >= 0:
            data_language[i] = 'Initial Teaching Alphabet'
        elif data_language[i].find('lat') >= 0:
            data_language[i] = 'Latin'
        elif data_language[i].find('srp') >= 0:
            data_language[i] = 'Serbian'
        elif data_language[i].find('rus') >= 0:
            data_language[i] = 'Russian'
        elif data_language[i].find('9.78067E+12') >= 0:
            data_language[i] = None
        elif data_language[i].find('9.78159E+12') >= 0:
            data_language[i] = None
        elif data_language[i].find('tur') >= 0:
            data_language[i] = 'Turkish'
        elif data_language[i].find('9.78156E+12') >= 0:
            data_language[i] = None
        elif data_language[i].find('msa') >= 0:
            data_language[i] = 'Modern Standard Arabic'
        elif data_language[i].find('swe') >= 0:
            data_language[i] = 'Swedish'
        elif data_language[i].find('glg') >= 0:
            data_language[i] = 'Galician'
        elif data_language[i].find('cat') >= 0:
            data_language[i] = 'Catalan'
        elif data_language[i].find('wel') >= 0:
            data_language[i] = 'Welsh'
        elif data_language[i].find('heb') >= 0:
            data_language[i] = 'Hebrew'
        elif data_language[i].find('nor') >= 0:
            data_language[i] = 'Murik'
        elif data_language[i].find('9.78186E+12') >= 0:
            data_language[i] = None
        elif data_language[i].find('9.78085E+12') >= 0:
            data_language[i] = None
        elif data_language[i].find('gla') >= 0:
            data_language[i] = 'Scottish Gaelic'
        elif data_language[i].find('ale') >= 0:
            data_language[i] = 'Afro-Asiatic'     
        elif data_language[i].find('9780674842113') >= 0:
            data_language[i] = None
        elif data_language[i].find('9781593600112') >= 0:
            data_language[i] = None
        elif data_language[i].find('9781563841552') >= 0:
            data_language[i] = None
        elif data_language[i].find('9780851742717') >= 0:
            data_language[i] = None

with open('new_kaggle_books_ann_ng.csv.csv', mode='w') as csv_file:
    csv_writer = csv.writer(csv_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)

    csv_writer.writerow(['ISBN','Name','Source','Author','Category','Publish year','Language','Publisher'])
    for i in range(len(data_name)):
        csv_writer.writerow([data_isbn10[i],data_name[i],data_source[i],data_author[i],data_category[i],
                             data_publishy[i],data_language[i],data_publiser[i]])
